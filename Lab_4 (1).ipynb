# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sns.set_style('whitegrid')

# %%
df = pd.read_csv('HousePrices.csv', index_col=0)
df
# Out:
#         price  lotsize  bedrooms  bathrooms  stories driveway recreation
# 1     42000.0     5850         3          1        2      yes         no  \
# 2     38500.0     4000         2          1        1      yes         no
# 3     49500.0     3060         3          1        1      yes         no
# 4     60500.0     6650         3          1        2      yes        yes
# 5     61000.0     6360         2          1        1      yes         no
# ..        ...      ...       ...        ...      ...      ...        ...
# 542   91500.0     4800         3          2        4      yes        yes
# 543   94000.0     6000         3          2        4      yes         no
# 544  103000.0     6000         3          2        4      yes        yes
# 545  105000.0     6000         3          2        2      yes        yes
# 546  105000.0     6000         3          1        2      yes         no
#
#     fullbase gasheat aircon  garage prefer
# 1        yes      no     no       1     no
# ...

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.FacetGrid.html - ссылка на документацию и примеры

# %%
sns.set_style('whitegrid')

g = sns.FacetGrid(df_bed, col="bedrooms", hue="driveway", height=4, palette='Set2')
g.map_dataframe(sns.scatterplot, x="price", y="lotsize")
g.set_axis_labels("Цена дома", "Размер участка")
g.set_titles(col_template="Количество спален = {col_name}")
g.add_legend(title="Подъездная дорога");

# %% [markdown]
# **Вывод**: Из графика можно сделать вывод, что среди объектов преобладают дома с количеством спален равным 3, также видно, что участок оранжевого цвета на всех графиках сосредоточен в левом нижнем углу и соотвествуют меньшей цене дома и размеру участка. Так можно сделать вывод о том, что чем правее располагается объект на графике, тем дороже он стоит и тем большее количество этажей имеет

# %%
sns.set_style('whitegrid')

g = sns.FacetGrid(df_bed, col="bedrooms", height=4, palette='Set2')
g.map_dataframe(sns.histplot, "price")
g.set_axis_labels(x_var="Цена дома", y_var=' ')
g.set_titles(col_template="Количество спален = {col_name}");

# %% [markdown]
# **Вывод**: чем больше количество спален находится в доме, тем правее располагается выпуклая часть графика (средняя цена растет)

# %%
sns.set_style('whitegrid')

g = sns.FacetGrid(df_bed, col="bedrooms", height=4, palette='Set2')
g.map_dataframe(sns.histplot, "lotsize")
g.set_axis_labels(x_var="Размер участка", y_var=' ')
g.set_titles(col_template="Количество спален = {col_name}");

# %% [markdown]
# **Вывод**: чем больше количество спален находится в доме, тем правее располагается выпуклая часть графика (средний размер участка растет)

# %%
sns.set_style('whitegrid')

g = sns.FacetGrid(df_bed, col="bedrooms", height=5, aspect=1, palette='Set2')
g.map_dataframe(sns.boxplot, y="price")
g.set_axis_labels(x_var="Цена дома", y_var=' ')
g.set_titles(col_template="Количество спален = {col_name}");

# %%
sns.set_style('whitegrid')

g = sns.FacetGrid(df_bed, col="bedrooms", height=5, aspect=1, palette='Set2')
g.map_dataframe(sns.boxplot, y="lotsize")
g.set_axis_labels(x_var="Размер участка", y_var=' ')
g.set_titles(col_template="Количество спален = {col_name}");

# %% [markdown]
# **Вывод**: чем больше количество спален находится в доме, тем выше располагается среднее значение размера участка и цены дома

# %%
sns.set_style('whitegrid')

g = sns.FacetGrid(df_bed, col="bedrooms", hue="stories", height=4, palette='Set2')
g.map_dataframe(sns.scatterplot, x="price", y="lotsize")
g.set_axis_labels("Цена дома", "Размер участка")
g.set_titles(col_template="Количество спален = {col_name}")
g.add_legend(title="Количество этажей");

# %% [markdown]
# **Вывод**: на первом графике видно, что большинство домов с количеством спален равным 2 имеют 1 этаж, для 3 и более спален большинством являются 2 этажа. Также видно, что область розового цвета (количество этажей = 4) на графиках 2 и 3 располагается правее (цена дома растет)

# %%
sns.set_style('whitegrid')

g = sns.FacetGrid(df_bed, col="driveway", hue='bedrooms', height=4, aspect=1, palette='Set2')
g.map_dataframe(sns.pointplot, "price")
g.set_axis_labels(x_var="Цена дома")
g.set_titles(col_template="Подъездная дорога = {col_name}")
g.add_legend(title="Количество спален");

# %%
sns.set_style('whitegrid')

g = sns.FacetGrid(df_bed, col="bedrooms", height=4, aspect=1, palette='Set2')
g.map_dataframe(sns.barplot, y="stories")
g.set_axis_labels(y_var="Количество этажей")
g.set_titles(col_template="Количество спален = {col_name}");

# %%
sns.set_style('whitegrid')

g = sns.FacetGrid(df_bed, col="bedrooms", height=4, aspect=1, palette='Set2')
g.map_dataframe(sns.barplot, y="bathrooms")
g.set_axis_labels(y_var="Количество ванных комнат")
g.set_titles(col_template="Количество спален = {col_name}");

# %%
sns.set_style('whitegrid')

g = sns.FacetGrid(df_bed, col="bedrooms", height=4, aspect=1, palette='Set2')
g.map_dataframe(sns.barplot, y="garage")
g.set_axis_labels(y_var="Количество мест в гараже")
g.set_titles(col_template="Количество спален = {col_name}");

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.PairGrid.html - ссылка на документацию и примеры

# %%
sns.pairplot(df_bed, hue ='bedrooms', corner=True, diag_kind="hist");

# %% [markdown]
# 1. **price** - цена дома (количественный признак) (Фунты стерлингов: 25000-190000)
# 2. **lotsize** - размер участка недвижимости (количественный признак) (Квадратные футы: 1650-16200)
# 3. **bedrooms** - количество спален (категориальный признак) (1, 2, 3, 4, 5, 6)
# 4. **bathrooms** - количество ванных комнат (категориальный признак) (1, 2, 3, 4)
# 5. **stories** - количество этажей без учета подвала (категориальный признак) (1, 2, 3, 4)
# 6. **driveway** - есть ли к дому подъездная дорога (бинарная переменная) (yes, no)
# 7. **recreation** - есть ли в доме комната отдыха (бинарная переменная) (yes, no)
# 8. **fullbase** - есть ли в доме полностью готовый подвал (бинарная переменная) (yes, no)
# 9. **gasheat** - используется ли в доме газ для нагрева горячей воды (бинарная переменная) (yes, no)
# 10. **aircon** - есть ли центральное кондиционирование воздуха (бинарная переменная) (yes, no)
# 11. **garage** - количество мест в гараже (количественный признак) (0, 1, 2, 3)
# 12. **prefer** - расположен ли дом в предпочтительном районе города (бинарная переменная) (yes, no)

# %%
https://seaborn.pydata.org/generated/seaborn.JointGrid.html - ссылка на документацию и примеры

# %%
sns.set_style('whitegrid')

g = sns.JointGrid(data=df_bed, x="price", y="lotsize", hue="bedrooms")
g.plot(sns.scatterplot, sns.histplot);

# %% [markdown]
# некоторые примеры Pair-сетки

# %%
iris = sns.load_dataset("iris")
g = sns.PairGrid(iris)
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(iris, hue="species")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
g = sns.PairGrid(iris, vars=["sepal_length", "sepal_width"], hue="species")
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(iris)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot, lw=3, legend=False)

# %%
tips = sns.load_dataset("tips")
g = sns.PairGrid(tips, y_vars=["tip"], x_vars=["total_bill", "size"], height=4)
g.map(sns.regplot, color=".3")
g.set(ylim=(-1, 11), yticks=[0, 5, 10])

# %%
g = sns.PairGrid(tips, hue="size", palette="GnBu_d")
g.map(plt.scatter, s=50, edgecolor="white")
g.add_legend()

# %%
sns.pairplot(iris, hue="species", height=2.5)

# %%
g = sns.pairplot(iris, hue="species", palette="Set2", diag_kind="kde", height=2.5)
